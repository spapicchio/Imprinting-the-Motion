# %% [markdown]
# #Install useful libraries

# %%
# !pip install tensorboardX

# %%
# !sudo apt-get install dos2unix

# %% [markdown]
# # Unzip the dataset

# %%
# !unzip "path to the zipped dataset"

# %% [markdown]
# # 1.1 convLSTM without attention

# %% [markdown]
# ## STAGE 1

# %%
# !cp final_Project/script/script_stage_1.bash /content/

# %%
# !chmod 777 /content/script_stage_1.bash

# %%
# !dos2unix /content/script_stage_1.bash
# Out:
# dos2unix: converting file /content/script_stage_1.bash to Unix format...

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_stage_1_no_attention"
# 3. **flag**="no_attention"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_1.bash

# %% [markdown]
# ## STAGE 2

# %%
# !cp final_Project/script/script_stage_2.bash /content/

# %%
# !chmod 777 /content/script_stage_2.bash

# %%
# !dos2unix /content/script_stage_2.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_stage_2_no_attention"
# 3. **flag**="no_attention"
# 4. **stage1Dict**="/content/output_stage_1"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_2.bash

# %% [markdown]
# # 1.2 convLSTM with attention

# %% [markdown]
# ### STAGE 1

# %%
# !cp /content/drive/MyDrive/Machine_Learning_Project/Google_Colabs/final_Project/script/script_stage_1.bash /content/

# %%
# !chmod 777 /content/script_stage_1.bash

# %%
# !dos2unix /content/script_stage_1.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="/content/drive/MyDrive/Machine_Learning_Project/Google_Colabs/final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_stage_1_attention"
# 3. **flag**="default"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_1.bash

# %% [markdown]
# ### STAGE 2

# %%
# !cp /content/drive/MyDrive/Machine_Learning_Project/Google_Colabs/final_Project/script/script_stage_2.bash /content/

# %%
# !chmod 777 /content/script_stage_2.bash

# %%
# !dos2unix /content/script_stage_2.bash

# %% [markdown]
# Unzip the folder with the weights of the model

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="/content/drive/MyDrive/Machine_Learning_Project/Google_Colabs/final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_stage_2_attention"
# 3. **flag**="default"
# 4. **stage1Dict**="/content/output_stage_1"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_2.bash

# %% [markdown]
# # 1.3 flow resnet

# %%
# !cp final_Project/script/script_flow.bash /content/

# %%
# !chmod 777 /content/script_flow.bash

# %%
# !dos2unix /content/script_flow.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_flow"
# 3. **flag**="flow"

# %% [markdown]
# **training**

# %%
# !/content/script_flow.bash

# %% [markdown]
# # 1.4 joint stream RGB with warp flow

# %% [markdown]
# ### STAGE 2

# %%
# !cp final_Project/script/script_stage_2.bash /content/

# %%
# !chmod 777 /content/script_stage_2.bash

# %%
# !dos2unix /content/script_stage_2.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_twoJoint"
# 3. **flag**="jointStream"
# 4. **rgbModel**="weight of the rgb model"
# 5. **flowModel**="weight of the flow model"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_2.bash

# %% [markdown]
# # 1.5 motion Segmentation

# %% [markdown]
# ## 1.5.1 classification

# %% [markdown]
# ### STAGE 2

# %%
# !cp final_Project/script/script_stage_2.bash /content/

# %%
# !chmod 777 /content/script_stage_2.bash

# %%
# !dos2unix /content/script_stage_2.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1. **main_run**="final_Project/main_run_self_supervised.py
# 2. **outDir**="/content/output_ms_classification"
# 3. **flag**="ms_class"
# 4. **stage1Dict**="best model convLSTM+attention stage 1"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_2.bash

# %% [markdown]
# ## 1.5.2 regression

# %% [markdown]
# ### STAGE 2

# %%
# !cp final_Project/script/script_stage_2.bash /content/

# %%
# !chmod 777 /content/script_stage_2.bash

# %%
# !dos2unix /content/script_stage_2.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_ms_regression"
# 3. **flag**="ms_regr"
# 4. **stage1Dict**="/content/output_ms_classification"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_2.bash

# %% [markdown]
# # 1.6 Variation

# %% [markdown]
# ### STAGE 2

# %%
# !cp final_Project/script/script_stage_2.bash /content/

# %%
# !chmod 777 /content/script_stage_2.bash

# %%
# !dos2unix /content/script_stage_2.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **main_run**="final_Project/main_run_self_supervised.py
# 2.   **outDir**="/content/output_variation_cl"
# 3. **flag**="variation_cl"
# 4. **stage1Dict**="best model dict convLSTM + attention stage1"

# %% [markdown]
# **training**

# %%
# !/content/script_stage_2.bash

# %% [markdown]
# # 1.7 Eval

# %%
! cp final_Project/script/script_eval.bash /content/script_eval.bash

# %%
# !chmod 777 /content/script_eval.bash

# %% [markdown]
# Change the parameter inside the script:
#
# 1.   **modelStateDict**="correct model"
# 2.   **flag**="correct flag"
# 3.   **seqLen**=16, 7, 5(warp network)

# %%
# !/content/script_eval.bash

# %% [markdown]
# # 1.8 Cam Generation

# %%
# !cp final_Project/script/generation_cam.bash /content/

# %%
# !chmod 777 /content/generation_cam.bash.bash

# %%
# !dos2unix /content/generation_cam.bash.bash

# %% [markdown]
# Paramters:
# 1. **dir_out**="/content/cam_output"
# 2. **model_dict**="correct model"

# %%
# !/content/generation_cam.bash
